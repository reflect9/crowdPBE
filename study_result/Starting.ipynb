# %% [raw]
# # ANALYZING LOG DATA OF CROWDPBE PROJECT

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json, csv
from pprint import pprint

# %%
reports = []
for i in range(0,30):
    with open('report'+str(i)+".json", mode='r') as infile:
        report = json.load(infile)
        reports.append(report)

# %%
# Identifying patterns of common mistakes

# %%
rs = pd.Series(reports)

# %%
df = pd.DataFrame(rs,columns=['all'])

# %%
df['mode']= df['all'].map(lambda x: x['mode'])

# %%
df['log'] = df['all'].map(lambda x: x['log'])

# %%
# extracting all file_messages
# per task
tid_list = ["tutorial_1", "tutorial_arith_1", "tutorial_arith_2", "tutorial_sum", "tutorial_text_extraction", "tutorial_filter_1", "task_three_step_arith", "task_number_sort", "task_filter_words_by_length", "task_filter_numbers", "task_extract_and_filter"]
code_list = ['EMPTY_CELL','INCONSISTENT_TYPE','FILTER_WITHOUT_TF','FILTER_AND_EXTRACT','TF_WITHOUT_NUMBER','NO_PROGRAM_FOUND']
df_fails = pd.DataFrame(0, index=tid_list, columns=code_list)
# fails_per_task = {tid:{} for tid in tid_list}
for report in reports: # report per participant
    if report['mode']=="baseline": 
        continue
    for tid in tid_list:
        temp_codes = {code:False for code in code_list}
        for ev in report['log']:
            if ev['tid']==tid and ev['event']=="FAIL_MESSAGE":
                for cd in ev['detail']['code']:
                     temp_codes[cd] = True
        for code in temp_codes:
            if temp_codes[code]==True:
                df_fails[code][tid] += 1

# %%
df_fails
# Out:
#                              EMPTY_CELL  INCONSISTENT_TYPE  FILTER_WITHOUT_TF  \
# tutorial_1                            0                  0                  0
# tutorial_arith_1                      0                  0                  0
# tutorial_arith_2                      2                  0                  0
# tutorial_sum                          0                  0                  0
# tutorial_text_extraction              0                  0                  0
# tutorial_filter_1                     2                  0                 11
# task_three_step_arith                 2                  0                  0
# task_number_sort                      0                  0                  0
# task_filter_words_by_length           1                  0                  9
# task_filter_numbers                   0                  0                 11
# task_extract_and_filter               2                  0                  3
#
#                              FILTER_AND_EXTRACT  TF_WITHOUT_NUMBER  \
# tutorial_1                                    0                  0
# tutorial_arith_1                              0                  0
# tutorial_arith_2                              0                  0
# tutorial_sum                                  0                  0
# tutorial_text_extraction                      0                  0
# tutorial_filter_1                             0                  3
# task_three_step_arith                         0                  0
# task_number_sort                              0                  0
# task_filter_words_by_length                   0                 12
# task_filter_numbers                           0                  0
# task_extract_and_filter                       0                  8
#
#                              NO_PROGRAM_FOUND
# tutorial_1                                  0
# tutorial_arith_1                            0
# tutorial_arith_2                            5
# tutorial_sum                                1
# tutorial_text_extraction                    0
# tutorial_filter_1                           8
# task_three_step_arith                       5
# task_number_sort                            2
# task_filter_words_by_length                 4
# task_filter_numbers                         5
# task_extract_and_filter                    15

# %%
mistakes = []
with open('mistakes.csv', mode='r') as infile:
    reader = csv.DictReader(infile, delimiter=',')
    for row in reader:
        mistakes.append(row)

# %%
dfm = pd.DataFrame(mistakes)

# %%
dfm
# Out:
#                                                 detail          feedback  \
# 0                For input+1, user provided 1->2 twice
# 1          For sorting, all outputs are reversed input
# 2          For sorting, all outputs are reversed input
# 3          For sorting, all outputs are reversed input
# 4             For sum, all outputs are counts of input
# 5         Insufficient to find the correct conditional
# 6         Insufficient to find the correct conditional
# 7         Insufficient to find the correct conditional
# 8         Insufficient to find the correct conditional
# 9         Insufficient to find the correct conditional
# 10        Insufficient to find the correct conditional
# 11        Insufficient to find the correct conditional
# 12        Insufficient to find the correct conditional
# 13                      kept trying with a single case
# 14                      kept trying with a single case
# 15                                         single case
# 16                                         single case
# 17                                         single case
# 18                                         single case
# 19                                         single case
# 20                                         single case
# 21                                         single case
# 22                                         single case
# 23                                         single case
# 24                                         single case
# 25                                         single case
# 26                                         single case
# 27                                         single case
# 28                                         single case
# 29                                         single case
# ..                                                 ...               ...
# 220  Providing input numbers and T,F at the same ti...
# 221  Providing input numbers and T,F at the same ti...  No_PROGRAM_FOUND
# 222  Providing input numbers and T,F at the same ti...  NO_PROGRAM_FOUND
# 223  Providing input numbers and T,F at the same ti...
# 224  Providing input numbers and T,F at the same ti...
# 225  Providing input numbers and T,F at the same ti...  NO_PROGRAM_FOUND
# 226      Providing single T or F when series is needed  NO_PROGRAM_FOUND
# 227      Providing single T or F when series is needed
# 228      Providing single T or F when series is needed  NO_PROGRAM_FOUND
# 229      Providing single T or F when series is needed
# 230      Providing single T or F when series is needed
# 231      Providing single T or F when series is needed
# 232      Providing single T or F when series is needed
# 233      Providing single T or F when series is needed
# 234      Providing single T or F when series is needed
# 235      Providing single T or F when series is needed  NO_PROGRAM_FOUND
# 236  Trying 'dfv' and 'cv', 'cv3', 'x' for unknown ...
# 237         Using "2", which is operand of conditional  NO_PROGRAM_FOUND
# 238                                  wrong calculation  NO_PROGRAM_FOUND
# 239                                  wrong calculation
# 240                                  wrong calculation
# 241                                  wrong calculation
# 242                                  wrong calculation
# 243                                  wrong calculation  NO_PROGRAM_FOUND
# 244                                  Wrong calculation
# 245                                  Wrong calculation
# 246                                  Wrong calculation
# 247           Wrong calculation (inconsistent T and F)  NO_PROGRAM_FOUND
# 248           Wrong calculation (inconsistent T and F)
# 249           Wrong calculation (inconsistent T and F)  NO_PROGRAM_FOUND
#
#     isCritical          mistake mode pid                          tid tii
# 0               Ambiguous cases    b  25             tutorial_arith_1   2
# 1               Ambiguous cases    e  15             task_number_sort   8
# 2               Ambiguous cases    b  19             task_number_sort   8
# 3               Ambiguous cases    e  27             task_number_sort   8
# 4               Ambiguous cases    e   7                 tutorial_sum   4
# 5         TRUE  Ambiguous cases    b   8          task_filter_numbers  10
# 6         TRUE  Ambiguous cases    b  12          task_filter_numbers  10
# 7         TRUE  Ambiguous cases    b  30          task_filter_numbers  10
# 8               Ambiguous cases    b  19          task_filter_numbers  10
# 9               Ambiguous cases    b  23          task_filter_numbers  10
# 10              Ambiguous cases    e  26          task_filter_numbers  10
# 11              Ambiguous cases    e  28          task_filter_numbers  10
# 12              Ambiguous cases    e  29          task_filter_numbers  10
# 13              Ambiguous cases    e  21        task_three_step_arith   7
# 14              Ambiguous cases    b  23        task_three_step_arith   7
# 15        TRUE  Ambiguous cases    b   4        task_three_step_arith   7
# 16        TRUE  Ambiguous cases    b   8        task_three_step_arith   7
# 17        TRUE  Ambiguous cases    b  12        task_three_step_arith   7
# 18        TRUE  Ambiguous cases    b  19        task_three_step_arith   7
# 19        TRUE  Ambiguous cases    b   4             task_number_sort   8
# 20        TRUE  Ambiguous cases    b  22             task_number_sort   8
# 21        TRUE  Ambiguous cases    b  30             task_number_sort   8
# 22        TRUE  Ambiguous cases    b  22          task_filter_numbers  10
# 23              Ambiguous cases    b   9             tutorial_arith_2   3
# 24              Ambiguous cases    b  12             tutorial_arith_2   3
# 25              Ambiguous cases    b  19             tutorial_arith_2   3
# 26              Ambiguous cases    b  20             tutorial_arith_2   3
# 27              Ambiguous cases    b  22             tutorial_arith_2   3
# 28              Ambiguous cases    b  23             tutorial_arith_2   3
# 29              Ambiguous cases    b  24             tutorial_arith_2   3
# ..         ...              ...  ...  ..                          ...  ..
# 220                  Wrong step    b  19            tutorial_filter_1   6
# 221                  Wrong step    e  15            tutorial_filter_1   6
# 222                  Wrong step    e  18      task_extract_and_filter  11
# 223                  Wrong step    b  22          task_filter_numbers  10
# 224                  Wrong step    b   9            tutorial_filter_1   6
# 225                  Wrong step    e  11            tutorial_filter_1   6
# 226       TRUE       Wrong step    e  15  task_filter_words_by_length   9
# 227       TRUE       Wrong step    b   6          task_filter_numbers  10
# 228                  Wrong step    e   2            tutorial_filter_1   6
# 229                  Wrong step    b   6            tutorial_filter_1   6
# 230                  Wrong step    b   8            tutorial_filter_1   6
# 231                  Wrong step    b   9            tutorial_filter_1   6
# 232                  Wrong step    b  25            tutorial_filter_1   6
# 233                  Wrong step    b   6             task_number_sort   8
# 234                  Wrong step    b   6  task_filter_words_by_length   9
# 235                  Wrong step    e  15          task_filter_numbers  10
# 236                  Wrong step    b  19                 tutorial_sum   4
# 237       TRUE       Wrong step    e  15  task_filter_words_by_length   9
# 238       TRUE       Wrong step    e  15        task_three_step_arith   7
# 239       TRUE       Wrong step    b  20        task_three_step_arith   7
# 240                  Wrong step    b   9        task_three_step_arith   7
# 241                  Wrong step    b  17        task_three_step_arith   7
# 242                  Wrong step    b  25        task_three_step_arith   7
# 243                  Wrong step    e  26        task_three_step_arith   7
# 244                  Wrong step    b  30        task_three_step_arith   7
# 245                  Wrong step    e  16          task_filter_numbers  10
# 246                  Wrong step    e  29          task_filter_numbers  10
# 247       TRUE       Wrong step    e  21      task_extract_and_filter  11
# 248                  Wrong step    b  17          task_filter_numbers  10
# 249                  Wrong step    e  27      task_extract_and_filter  11
#
# [250 rows x 8 columns]

# %%
# COUNTING MISTAKES PER TASK
mistakesPerTask = []
for i in range(7,12):
    mistakesPerTask.append(len(dfm[dfm.tii==str(i)]))
series = pd.Series(mistakesPerTask, index=range(7,12))
print series
# series.describe()
# Out:
# 7     30
# 8     15
# 9     44
# 10    42
# 11    49
# dtype: int64

# %%
# COUNTING % OF TASKS(tii*pi) THAT WE FOUND MISTAKES
numTasks = 0
numTasksWithMistake = 0
numMistakePerTask = []
for tii in range(7,12):
    row = []
    for pi in range(0,30):
        num = len(dfm[(dfm.tii==str(tii)) & (dfm.pid==str(pi))])
        row.append(num)
        if num>0:
            numTasksWithMistake += 1
        numTasks += 1
    numMistakePerTask.append(row)
print numTasks
print numTasksWithMistake
print "% OF TASKS(TASK*PARTICIPANT) THAT HAS AT LEAST ONE MISTAKE: ", float(numTasksWithMistake) / numTasks
# Out:
# 150
# 111
# % OF TASKS(TASK*PARTICIPANT) THAT HAS AT LEAST ONE MISTAKE:  0.74

# %%
# COUNTING HOW MANY DATA POINTS (150 = 30 participants done 5 tasks) 
count = 0
datapoints = []
for tii in range(1,12):
    for pi in range(0,30):
        datapoints.append(len(dfm[(dfm.tii==str(tii)) & (dfm.pid==str(pi))]))
        if len(dfm[(dfm.tii==str(tii)) & (dfm.pid==str(pi))])>0:
            count += 1
print count
print float(count) / 150.0
print pd.Series(datapoints).describe()
# mistakesPerDataPoints = {tii:{ pi:len(dfm[(dfm.tii==str(tii)) & (dfm.pid==str(pi))]) for pi in range(0,30) } for tii in range(1,11)}
# percDataPointsContainingMistakes =
# Out:
# 154
# 1.02666666667
# count    330.000000
# mean       0.706061
# std        0.876037
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        4.000000
# dtype: float64

# %%
# MAKING DATAFRAME OF TASK and MISTAKE TYPE
mistakes = dfm['mistake'].unique()
dict_mistake = {tii:{m:0 for m in mistakes} for tii in range(7,12)}
critical_mistakes = {m:0 for m in mistakes} 
for entry in dfm.T.to_dict().values():
    mistake = entry['mistake']
    tii = int(entry['tii'])
    if tii>6:
        dict_mistake[tii][mistake] += 1
    if entry['isCritical']:
        critical_mistakes[mistake] += 1
print critical_mistakes
        
# print dict_mistake
df_mistakes = pd.DataFrame(dict_mistake)
df_mistakes['total'] = df_mistakes.sum(axis=1)
print df_mistakes
# Out:
# {'Trying formula': 7, 'Unnecessary steps': 6, 'Ambiguous cases': 11, 'Wrong input': 1, 'Wrong step': 7, 'Wrong program': 2, 'Empty cases': 0, 'Missing step': 30}
#                     7  8   9  10  11  total
# Ambiguous cases    10  7   0  12   0     29
# Empty cases         1  0   1   0   0      2
# Missing step        4  0  33  17  38     92
# Trying formula      3  3   2   2   1     11
# Unnecessary steps   3  1   3   5   3     15
# Wrong input         0  0   0   0   1      1
# Wrong program       2  0   0   0   1      3
# Wrong step          7  4   5   6   5     27

# %%
dfm['mistake'].value_counts()
len(dfm['mistake'])
# Out:
# 250

# %%
dfm[dfm.isCritical=='TRUE']['mistake'].value_counts()
float(len(dfm[dfm.isCritical=='TRUE']['mistake'])) / len(dfm['mistake'])
# Out:
# 0.256
